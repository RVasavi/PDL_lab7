# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.master("local").appName("how to read csv file").getOrCreate()

# %%
spark.version
# Out:
# Out[6]: '3.2.1'

# %%
df = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/shared_uploads/ds215229143@bhc.edu.in/Result_csv.csv")

# %%
type(df)
# Out:
# Out[8]: pyspark.sql.dataframe.DataFrame

# %%
df.show(5)
# Out:
# +-----------------+--------------------+-----------+-------------+------------------+---------+-------------------+-----------------+---------------------+--------------+---------------------------+-------------+--------------------------+-----------+--------+----------------+-----------------+----------------+--------+------------+------------+------------+--------------------------+-----------+
# |        Timestamp|       Email Address|roll number|         name|       department |MFDS mark|NOSQL (theory) mark|PSPR (theory)mark|ESDS(statistics) mark|NOSQL lab mark|Data visualization lab mark|PSPR lab mark|overall percentage in Sem1|result sem1|TSA mark|PML (theory)mark|NLP (theory) mark|DVA(theory) mark|HCD mark|DVA lab mark|PML lab mark|NLP lab mark|overall percentage in sem2|result sem2|
# ...

# %%
student = df.count()
print("Total Number of Students:",student)
# Out:
# Total Number of Students: 37

# %%
df.avg('overall percentage in Sem1')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <command-1567180300654327> in <module>
# ----> 1 df.avg('overall percentage in Sem1')
#
# /databricks/spark/python/pyspark/sql/dataframe.py in __getattr__(self, name)
#    1798         """
#    1799         if name not in self.columns:
# -> 1800             raise AttributeError(
#    1801                 "'%s' object has no attribute '%s'" % (self.__class__.__name__, name))
#    1802         jc = self._jdf.apply(name)
#
# AttributeError: 'DataFrame' object has no attribute 'avg'

# %%
df.describe()
# Out:
# Out[22]: DataFrame[summary: string, Timestamp: string, Email Address: string, roll number: string, name: string, department : string, MFDS mark: string, NOSQL (theory) mark: string, PSPR (theory)mark: string, ESDS(statistics) mark: string, NOSQL lab mark: string, Data visualization lab mark: string, PSPR lab mark: string, overall percentage in Sem1: string, result sem1: string, TSA mark: string, PML (theory)mark: string, NLP (theory) mark: string, DVA(theory) mark: string, HCD mark: string, DVA lab mark: string, PML lab mark: string, NLP lab mark: string, overall percentage in sem2: string, result sem2: string]

# %%
df.null().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <command-1567180300654329> in <module>
# ----> 1 df.null().sum()
#
# /databricks/spark/python/pyspark/sql/dataframe.py in __getattr__(self, name)
#    1798         """
#    1799         if name not in self.columns:
# -> 1800             raise AttributeError(
#    1801                 "'%s' object has no attribute '%s'" % (self.__class__.__name__, name))
#    1802         jc = self._jdf.apply(name)
#
# AttributeError: 'DataFrame' object has no attribute 'null'
